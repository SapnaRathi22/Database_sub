# %%
import sqlite3 as sql
import pandas as pd

# %%
conn = sql.connect('database.sqlite')
conn

# %%
def sql_query(q):
    return pd.read_sql_query(q,conn)

# %%
q= '''SELECT name FROM sqlite_master'''
sql_query(q)
# Out:
#                 name
# 0           Salaries
# 1  salaries_year_idx

# %% [markdown]
# # Select Statement

# %%
#Select All Columns Using * 
q= '''SELECT * FROM Salaries'''
sql_query(q)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
#Select Specific Columns
q= '''SELECT ID, employeeName , Jobtitle  FROM Salaries'''
sql_query(q)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                      CAPTAIN III (POLICE DEPARTMENT)
# 2                      CAPTAIN III (POLICE DEPARTMENT)
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                                                ...
# 148649                                       Custodian
# 148650                                    Not provided
# ...

# %%
#Select Columns with Aliases
q= '''SELECT S.ID, S.employeeName , S.Jobtitle  FROM Salaries S'''
sql_query(q)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                      CAPTAIN III (POLICE DEPARTMENT)
# 2                      CAPTAIN III (POLICE DEPARTMENT)
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                                                ...
# 148649                                       Custodian
# 148650                                    Not provided
# ...

# %%
#Select Columns with Aliases
q= '''SELECT ID, employeeName as name , Jobtitle job  FROM Salaries '''
sql_query(q)
# Out:
#             Id               name  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                                    job
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                      CAPTAIN III (POLICE DEPARTMENT)
# 2                      CAPTAIN III (POLICE DEPARTMENT)
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                                                ...
# 148649                                       Custodian
# 148650                                    Not provided
# ...

# %%
#Select Distinct Columns
q= '''SELECT DISTINCT Jobtitle job_types FROM Salaries '''
sql_query(q)
# Out:
#                                            job_types
# 0     GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                    CAPTAIN III (POLICE DEPARTMENT)
# 2               WIRE ROPE CABLE MAINTENANCE MECHANIC
# 3       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 4                          ASSISTANT DEPUTY CHIEF II
# ...                                              ...
# 2154                    Sr Cnselor, Juv Hall (SFERS)
# 2155                  Forensic Toxicologist Supervis
# 2156                                      Conversion
# 2157                                       Cashier 3
# 2158                                    Not provided
#
# [2159 rows x 1 columns]

# %%
# Select Columns Using Expressions or Calculations
q= '''SELECT totalpay+totalpaybenefits as salary  FROM Salaries '''
sql_query(q)
# Out:
#             salary
# 0       1135190.86
# 1       1077818.56
# 2        670559.82
# 3        664687.22
# 4        652746.38
# ...            ...
# 148649        0.00
# 148650        0.00
# 148651        0.00
# 148652        0.00
# 148653    -1236.26
#
# [148654 rows x 1 columns]

# %%
# Select Columns Using Expressions or Calculations
q= '''SELECT  Employeename||" "||jobtitle as name_and_job  FROM Salaries '''
sql_query(q)
# Out:
#                                              name_and_job
# 0       NATHANIEL FORD GENERAL MANAGER-METROPOLITAN TR...
# 1            GARY JIMENEZ CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG WIRE ROPE CABLE MAINTENANCE ...
# 4       PATRICK GARDNER DEPUTY CHIEF OF DEPARTMENT,(FI...
# ...                                                   ...
# 148649                            Roy I Tillery Custodian
# 148650                          Not provided Not provided
# 148651                          Not provided Not provided
# 148652                          Not provided Not provided
# 148653               Joe Lopez Counselor, Log Cabin Ranch
#
# [148654 rows x 1 columns]

# %%
#Select Distinct Columns
q= '''SELECT DISTINCT status
FROM Salaries '''
sql_query(q)
# Out:
#   Status
# 0
# 1     PT
# 2     FT

# %%
#Select Columns Using CASE Statements 
q = '''SELECT EmployeeName,
       CASE
         WHEN Status = 'PT' THEN 'High' 
         WHEN Status = 'FT' THEN 'Low'
         ELSE 'Unknown'
       END AS Category
FROM Salaries; '''
sql_query(q)
# Out:
#              EmployeeName Category
# 0          NATHANIEL FORD  Unknown
# 1            GARY JIMENEZ  Unknown
# 2          ALBERT PARDINI  Unknown
# 3       CHRISTOPHER CHONG  Unknown
# 4         PATRICK GARDNER  Unknown
# ...                   ...      ...
# 148649      Roy I Tillery     High
# 148650       Not provided  Unknown
# 148651       Not provided  Unknown
# 148652       Not provided  Unknown
# 148653          Joe Lopez     High
#
# [148654 rows x 2 columns]

# %% [markdown]
# # Where Clause

# %%
q= ''' select EmployeeName as name , jobtitle from Salaries 
   where jobtitle = "GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY"  '''
sql_query(q)
# Out:
#              name                                        JobTitle
# 0  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1  EDWARD REISKIN  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY

# %%
q= ''' select EmployeeName as name , jobtitle, totalpay , Basepay from Salaries 
   where Basepay >= 134401 and totalpay >=  332343.61	 '''
sql_query(q)
# Out:
#                     name                                        JobTitle  \
# 0         NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1           GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2         ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3         Gregory P Suhr                                 Chief of Police
# 4   Joanne M Hayes-White                          Chief, Fire Department
# 5            Samson  Lai                  Battalion Chief, Fire Suppress
# 6        Ellen G Moffatt                               Asst Med Examiner
# 7       David L Franklin                    Asst Chf of Dept (Fire Dept)
# 8             Amy P Hart                               Asst Med Examiner
# 9   William J Coaker Jr.                        Chief Investment Officer
# 10       Ellen G Moffatt                               Asst Med Examiner
# 11            Samson Lai                  Battalion Chief, Fire Suppress
#
# ...

# %%
# IN
q= ''' select EmployeeName as name , jobtitle From  Salaries 
   where jobtitle IN ('Custodian','CAPTAIN III (POLICE DEPARTMENT)', 'WIRE ROPE CABLE MAINTENANCE MECHANIC')	 '''
sql_query(q)
# Out:
#                     name                              JobTitle
# 0           GARY JIMENEZ       CAPTAIN III (POLICE DEPARTMENT)
# 1         ALBERT PARDINI       CAPTAIN III (POLICE DEPARTMENT)
# 2      CHRISTOPHER CHONG  WIRE ROPE CABLE MAINTENANCE MECHANIC
# 3       PATRICIA JACKSON       CAPTAIN III (POLICE DEPARTMENT)
# 4             ANNA BROWN       CAPTAIN III (POLICE DEPARTMENT)
# ...                  ...                                   ...
# 2458         Lian Xiu Wu                             Custodian
# 2459  George S Dela Pena                             Custodian
# 2460   Richard A Talbert                             Custodian
# 2461         Leon Walker                             Custodian
# 2462       Roy I Tillery                             Custodian
#
# [2463 rows x 2 columns]

# %%
# NOT IN
q= ''' select EmployeeName as name , jobtitle From  Salaries 
   where jobtitle NOT IN ('Custodian','CAPTAIN III (POLICE DEPARTMENT)', 'WIRE ROPE CABLE MAINTENANCE MECHANIC')	 '''
sql_query(q)
# Out:
#                    name                                        JobTitle
# 0        NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 2        DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 3             ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 4         DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# ...                 ...                                             ...
# 146186   Joann Anderson                     Communications Dispatcher 2
# 146187     Not provided                                    Not provided
# 146188     Not provided                                    Not provided
# 146189     Not provided                                    Not provided
# 146190        Joe Lopez                      Counselor, Log Cabin Ranch
#
# [146191 rows x 2 columns]

# %%
#Between
q= ''' select EmployeeName as name , jobtitle , Basepay from Salaries 
       where Basepay between 134401 and 332343.61	 '''
sql_query(q)
# Out:
#                   name                                        JobTitle  \
# 0       NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1         GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2       ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3      PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 4        DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# ...                ...                                             ...
# 8291  France Pean-Rush                                   Special Nurse
# 8292  Lormita C Nofies                                   Special Nurse
# 8293    Inder K Narula                                   Special Nurse
# 8294    Lisa Trueblood                                   Special Nurse
# 8295     Hye Shin Yang                                   Special Nurse
#
#         BasePay
# 0     167411.18
# 1     155966.02
# 2     212739.13
# 3     134401.60
# 4     256576.96
# ...

# %%
#IS NULL
q= ''' select EmployeeName as name , jobtitle  from Salaries 
       where Jobtitle is NULL	 '''
sql_query(q)
# Out:
# Empty DataFrame
# Columns: [name, JobTitle]
# Index: []

# %%
#IS NULL
q= ''' select EmployeeName as name , jobtitle  from Salaries 
       where Jobtitle is not NULL	 '''
sql_query(q)
# Out:
#                      name                                        JobTitle
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
# [148654 rows x 2 columns]

# %% [markdown]
# # Wildcard Characters in where clause

# %%
#%
q= ''' select EmployeeName as name , jobtitle  from Salaries 
       where Jobtitle like '%MAINTENANCE%'	 '''
sql_query(q)
# Out:
#                    name                                JobTitle
# 0     CHRISTOPHER CHONG    WIRE ROPE CABLE MAINTENANCE MECHANIC
# 1            KHOA TRINH       ELECTRONIC MAINTENANCE TECHNICIAN
# 2          NELSON ACETO  WIRE ROPE CABLE MAINTENANCE SUPERVISOR
# 3               WING NG       ELECTRONIC MAINTENANCE TECHNICIAN
# 4         ERIBERTO ISON       ELECTRONIC MAINTENANCE TECHNICIAN
# ...                 ...                                     ...
# 1188      Jose M Flores                Track Maintenance Worker
# 1189   Dante L Mcdaniel                Track Maintenance Worker
# 1190     Ian C Anonuevo             Electronic Maintenance Tech
# 1191  Antonio A Andrade                Track Maintenance Worker
# 1192      David A Plyer                Sewer Maintenance Worker
#
# [1193 rows x 2 columns]

# %%
#%
q= ''' select EmployeeName as name , jobtitle  from Salaries 
       where Jobtitle like 'MAINTENANCE%'	 '''
sql_query(q)
# Out:
#                     name               JobTitle
# 0         LARRY MITCHELL  MAINTENANCE MACHINIST
# 1        BIENVENIDO VEGA  MAINTENANCE MACHINIST
# 2             ANDRE KURY  MAINTENANCE MACHINIST
# 3              JOE GAUCI  MAINTENANCE MACHINIST
# 4         CESAR GONZALES  MAINTENANCE MACHINIST
# ..                   ...                    ...
# 371  David D Sanguinetti    Maintenance Planner
# 372         Andre J Kury  Maintenance Machinist
# 373      Danny D Humrich  Maintenance Machinist
# 374         John G Magri  Maintenance Machinist
# 375      Michael C Lydon  Maintenance Machinist
#
# [376 rows x 2 columns]

# %%
#_
q= ''' select EmployeeName as name , jobtitle  from Salaries 
       where Jobtitle like '___todian'	 '''
sql_query(q)
# Out:
#                        name   JobTitle
# 0                  TOM MACH  CUSTODIAN
# 1            JOSEPH FREEMAN  CUSTODIAN
# 2     HUGO BERRIOS-GONZALEZ  CUSTODIAN
# 3            FENG LING YANG  CUSTODIAN
# 4                ZHEN-LI LI  CUSTODIAN
# ...                     ...        ...
# 3209            Lian Xiu Wu  Custodian
# 3210     George S Dela Pena  Custodian
# 3211      Richard A Talbert  Custodian
# 3212            Leon Walker  Custodian
# 3213          Roy I Tillery  Custodian
#
# [3214 rows x 2 columns]

# %%
#_
q= ''' select EmployeeName as name , jobtitle  from Salaries 
       where  EmployeeName like 'R_y%'	 '''
sql_query(q)
# Out:
#                    name                               JobTitle
# 0        RAYMOND GUZMAN     BATTALION CHIEF, (FIRE DEPARTMENT)
# 1          RAY CRAWFORD  CAPTAIN, EMERGENCYCY MEDICAL SERVICES
# 2        RAYMOND KOENIG                       POLICE OFFICER I
# 3        RAYMOND CHAVEZ                            FIREFIGHTER
# 4       RAYCARDO AVILES                            FIREFIGHTER
# ..                  ...                                    ...
# 762  Raymond R Meredith                 Public Service Trainee
# 763   Raymond A Whitley         Custodial Assistant Supervisor
# 764      Roy J King Iii                      Recreation Leader
# 765         Roy Kaushik               Commissioner No Benefits
# 766       Roy I Tillery                              Custodian
#
# [767 rows x 2 columns]

# %%
#_
q= ''' select EmployeeName as name , jobtitle  from Salaries 
       where  jobtitle like '[FIR]'	 '''
sql_query(q)    ###not working due to REGEXP Support:
# Out:
# Empty DataFrame
# Columns: [name, JobTitle]
# Index: []

# %%
#_
q= ''' select Id , EmployeeName as name , jobtitle  from Salaries 
       where  Id like '[1-9]'	
    '''
sql_query(q)     ###not working due to REGEXP Support:
# Out:
# Empty DataFrame
# Columns: [Id, name, JobTitle]
# Index: []

# %%
#_
q= ''' select  EmployeeName as name , jobtitle  from Salaries 
       where name like '%[^S]%'
    '''
sql_query(q)        ###not working due to REGEXP Support:
# Out:
# Empty DataFrame
# Columns: [name, JobTitle]
# Index: []

# %% [markdown]
# # ORDER BY

# %%
q= ''' select  EmployeeName as name , jobtitle , totalpay from Salaries 
       order by totalpay
    '''
sql_query(q)
# Out:
#                       name                                        JobTitle  \
# 0                Joe Lopez                      Counselor, Log Cabin Ranch
# 1           PAULETTE ADAMS      STATIONARY ENGINEER, WATER TREATMENT PLANT
# 2            KAUKAB MOHSIN                                TRANSIT OPERATOR
# 3       JOSEPHINE MCCREARY                                      MANAGER IV
# 4            Roland Baylon                           Deputy Court Clerk II
# ...                    ...                                             ...
# 148649      Gary Altenberg                    Lieutenant, Fire Suppression
# 148650          Amy P Hart                               Asst Med Examiner
# 148651         David Shinn                                  Deputy Chief 3
# 148652        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 148653      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#          TotalPay
# 0         -618.13
# 1            0.00
# ...

# %%
q= ''' select  EmployeeName as name , jobtitle , totalpay from Salaries 
       where totalpay > 457433
       order by totalpay DESC
    '''
sql_query(q)
# Out:
#              name                                        JobTitle   TotalPay
# 0  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  567595.43
# 1    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)  538909.28
# 2     David Shinn                                  Deputy Chief 3  471952.64

# %%
q= ''' select  EmployeeName as name , jobtitle , totalpay from Salaries 
       where totalpay > 457433
       order by 2 DESC
    '''
sql_query(q)
# Out:
#              name                                        JobTitle   TotalPay
# 0  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  567595.43
# 1     David Shinn                                  Deputy Chief 3  471952.64
# 2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)  538909.28

# %% [markdown]
# # Group By

# %%
q= ''' select  count(EmployeeName), jobtitle  from Salaries 
       Group by jobtitle
    
    '''
sql_query(q)
# Out:
#       count(EmployeeName)                                        JobTitle
# 0                      83                                   ACCOUNT CLERK
# 1                       5                                      ACCOUNTANT
# 2                      48                               ACCOUNTANT INTERN
# 3                       1                     ACPO,JuvP, Juv Prob (SFERS)
# 4                       1                                   ACUPUNCTURIST
# ...                   ...                                             ...
# 2154                   26                           X-RAY LABORATORY AIDE
# 2155                  100                           X-Ray Laboratory Aide
# 2156                    1  YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS
# 2157                    4                              Youth Comm Advisor
# 2158                    1                                     ZOO CURATOR
#
# [2159 rows x 2 columns]

# %%
q= ''' select  count(EmployeeName), jobtitle ,  totalpay from Salaries 
       where totalpay> 77643
       Group by jobtitle
    
    '''
sql_query(q)
# Out:
#       count(EmployeeName)                            JobTitle   TotalPay
# 0                       2              ADMINISTRATIVE ANALYST   79754.03
# 1                       2          ADMINISTRATIVE ANALYST III   92847.00
# 2                      10             ADMINISTRATIVE ENGINEER  149322.23
# 3                       2     ADMINISTRATIVE SERVICES MANAGER   92002.00
# 4                       1  ADMINISTRATOR, SFGH MEDICAL CENTER  257124.44
# ...                   ...                                 ...        ...
# 1576                    3          Wire Rope Cable Maint Sprv  224833.47
# 1577                    8          Worker's Comp Supervisor 1  101722.05
# 1578                   47      Worker's Compensation Adjuster   81768.38
# 1579                    1               X-RAY LABORATORY AIDE   85077.40
# 1580                    8               X-Ray Laboratory Aide   88546.07
#
# [1581 rows x 3 columns]

# %%
q= ''' select  jobtitle , max( totalpay) as max_salary  , min(totalpay) as min_salary  from Salaries 
       Group by jobtitle 
    '''
sql_query(q)
# Out:
#                                             JobTitle  max_salary  min_salary
# 0                                      ACCOUNT CLERK    60838.20      614.00
# 1                                         ACCOUNTANT    65392.01     1148.40
# 2                                  ACCOUNTANT INTERN    58799.53     2981.53
# 3                        ACPO,JuvP, Juv Prob (SFERS)    62290.78    62290.78
# 4                                      ACUPUNCTURIST    67594.40    67594.40
# ...                                              ...         ...         ...
# 2154                           X-RAY LABORATORY AIDE    85077.40     5343.69
# 2155                           X-Ray Laboratory Aide    99812.97     1007.00
# 2156  YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    53632.87    53632.87
# 2157                              Youth Comm Advisor    57544.73    19212.71
# 2158                                     ZOO CURATOR    66686.56    66686.56
#
# [2159 rows x 3 columns]

# %%
q= ''' select  jobtitle , max( totalpay) as max_salary  , min(totalpay) as min_salary ,  year  from Salaries 
       Group by jobtitle , year 
    '''
sql_query(q)
# Out:
#                                             JobTitle  max_salary  min_salary  \
# 0                                      ACCOUNT CLERK    60838.20      614.00
# 1                                         ACCOUNTANT    65392.01     1148.40
# 2                                  ACCOUNTANT INTERN    58799.53     2981.53
# 3                        ACPO,JuvP, Juv Prob (SFERS)    62290.78    62290.78
# 4                                      ACUPUNCTURIST    67594.40    67594.40
# ...                                              ...         ...         ...
# 4132  YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    53632.87    53632.87
# 4133                              Youth Comm Advisor    57544.73    57544.73
# 4134                              Youth Comm Advisor    52433.88    19212.71
# 4135                              Youth Comm Advisor    36465.91    36465.91
# 4136                                     ZOO CURATOR    66686.56    66686.56
#
#       Year
# 0     2011
# 1     2011
# ...

# %%
q= ''' select EmployeeName , jobtitle , max(totalpay) from Salaries 
       Group by jobtitle
       order by jobtitle desc 
    '''
sql_query(q)
# Out:
#                EmployeeName                                        JobTitle  \
# 0               MYRON SULAK                                     ZOO CURATOR
# 1             Mario Yedidia                              Youth Comm Advisor
# 2             MARIO YEDIDIA  YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS
# 3         Omar Enzio A Lola                           X-Ray Laboratory Aide
# 4               DELBERT LEE                           X-RAY LABORATORY AIDE
# ...                     ...                                             ...
# 2154                 WEN XU                                   ACUPUNCTURIST
# 2155  Palminder K Hernandez                     ACPO,JuvP, Juv Prob (SFERS)
# 2156             PENG HUANG                               ACCOUNTANT INTERN
# 2157       CARLITO NEPACENA                                      ACCOUNTANT
# 2158         NAPOLEON VIRAY                                   ACCOUNT CLERK
#
#       max(totalpay)
# 0          66686.56
# ...

# %% [markdown]
# # limit

# %%
q= ''' select EmployeeName , jobtitle , max(totalpay) from Salaries 
       Group by jobtitle
       order by jobtitle desc 
       limit 10
    '''
sql_query(q)
# Out:
#           EmployeeName                                        JobTitle  \
# 0          MYRON SULAK                                     ZOO CURATOR
# 1        Mario Yedidia                              Youth Comm Advisor
# 2        MARIO YEDIDIA  YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS
# 3    Omar Enzio A Lola                           X-Ray Laboratory Aide
# 4          DELBERT LEE                           X-RAY LABORATORY AIDE
# 5       Penny I Colaco                  Worker's Compensation Adjuster
# 6     Linda  Bernstein                      Worker's Comp Supervisor 1
# 7         Nelson Aceto                      Wire Rope Cable Maint Sprv
# 8  Christopher C Chong                  Wire Rope Cable Maint Mechanic
# 9     Jose O Bojorquez                       Window Cleaner Supervisor
#
#    max(totalpay)
# 0       66686.56
# 1       57544.73
# 2       53632.87
# 3       99812.97
# 4       85077.40
# 5      106050.66
# 6      108810.03
# 7      224833.47
# 8      189630.64
# ...

# %% [markdown]
# # Having

# %%
q= ''' select  count(EmployeeName), jobtitle  from Salaries 
       Group by jobtitle
       having  count(EmployeeName)>10
       order by  count(EmployeeName) desc
    '''
sql_query(q)
# Out:
#       count(EmployeeName)                                     JobTitle
# 0                    7036                             Transit Operator
# 1                    4389                                Special Nurse
# 2                    3736                             Registered Nurse
# 3                    2518                 Public Svc Aide-Public Works
# 4                    2421                             Police Officer 3
# ...                   ...                                          ...
# 1151                   11     AUTOMOTIVE MECHANIC ASSISTANT SUPERVISOR
# 1152                   11                ASSOCIATE PERFORMANCE AUDITOR
# 1153                   11  ASSISTANT ELECTRONIC MAINTENANCE TECHNICIAN
# 1154                   11                       ARTS PROGRAM ASSISTANT
# 1155                   11                          APPRENTICE GARDENER
#
# [1156 rows x 2 columns]
